# %%
import pandas as pd

#load dataset
df = pd.read_csv(r"C:\Users\byobd\OneDrive\Desktop\Data-Analysis-And-Automation\Sample Data\data_jobs.csv")
df.head()

# cleaning the dataset
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN              NaN              NaN
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore         NaN              NaN              NaN
# 785737        Germany         NaN              NaN              NaN
# 785738       Malaysia         NaN              NaN              NaN
# 785739          Sudan         NaN              NaN              NaN
# 785740          India         NaN              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df_kenya = df[df['job_country'] == 'Kenya'].copy()

# %%
df_kenya
# Out:
#               job_title_short  \
# 1059           Cloud Engineer
# 1705             Data Analyst
# 2089           Data Scientist
# 2279           Data Scientist
# 3482             Data Analyst
# ...                       ...
# 783724         Data Scientist
# 784558         Cloud Engineer
# 784798  Senior Data Scientist
# 784991         Cloud Engineer
# 785115           Data Analyst
#
#                                                 job_title    job_location  \
# 1059                 Navigation & Infrastructure Engineer  Nairobi, Kenya
# 1705    Data Analytics Program Manager, VisionFund Int...  Nairobi, Kenya
# 2089                                       Data Scientist  Nairobi, Kenya
# 2279                                     Director of Data           Kenya
# 3482                                         Data Analyst  Nairobi, Kenya
# ...                                                   ...             ...
# 783724                   Data Science Intern at Dataposit  Nairobi, Kenya
# 784558     Data Insights Analytics Cloud Support Engineer  Nairobi, Kenya
# 784798                                     Senior Analyst  Nairobi, Kenya
# 784991                      Senior Engineering Technician  Nairobi, Kenya
# 785115                                      Data Analyst.  Nairobi, Kenya
#
#                    job_via         job_schedule_type  job_work_from_home  \
# 1059       via Trabajo.org                 Full-time               False
# 1705          via MyJobMag                 Full-time               False
# 2089       via Trabajo.org                 Full-time               False
# 2279       via Trabajo.org                 Full-time               False
# 3482          via UNjobnet                 Full-time               False
# ...                    ...                       ...                 ...
# 783724     via BeBee Kenya  Full-time and Internship               False
# 784558  via BrighterMonday                 Full-time               False
# 784798     via BeBee Kenya                 Full-time               False
# 784991     via Trabajo.org                 Full-time               False
# 785115     via Trabajo.org                 Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 1059             Kenya 2023-08-06 13:50:21                  False
# 1705             Kenya 2023-02-09 13:40:24                  False
# 2089             Kenya 2023-05-25 13:39:11                  False
# 2279             Kenya 2023-05-25 13:39:14                   True
# 3482             Kenya 2023-03-22 13:47:56                  False
# ...                ...                 ...                    ...
# 783724           Kenya 2023-09-18 06:19:21                  False
# 784558           Kenya 2023-11-16 06:31:16                  False
# 784798           Kenya 2023-10-29 06:22:25                  False
# 784991           Kenya 2023-08-12 06:19:49                   True
# 785115           Kenya 2023-05-31 06:25:53                  False
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 1059                   False       Kenya         NaN              NaN
# 1705                   False       Kenya         NaN              NaN
# 2089                   False       Kenya         NaN              NaN
# 2279                   False       Kenya         NaN              NaN
# 3482                   False       Kenya         NaN              NaN
# ...                      ...         ...         ...              ...
# 783724                 False       Kenya         NaN              NaN
# 784558                 False       Kenya         NaN              NaN
# 784798                 False       Kenya         NaN              NaN
# 784991                 False       Kenya         NaN              NaN
# 785115                 False       Kenya         NaN              NaN
#
#         salary_hour_avg                                       company_name  \
# 1059                NaN                                      Kenya Airways
# 1705                NaN                                 World Vision Kenya
# 2089                NaN                                     Medtronic Labs
# 2279                NaN                                      KOKO NETWORKS
# 3482                NaN         United Nations Human Settlements Programme
# ...                 ...                                                ...
# 783724              NaN                                          Dataposit
# 784558              NaN                                       confidential
# 784798              NaN                 Habitat for Humanity International
# 784991              NaN  Kenya Marine and Fisheries Research Institute ...
# 785115              NaN                                            Supreme
#
#                                                job_skills  \
# 1059                                                  NaN
# 1705                                          ['tableau']
# 2089                    ['go', 'python', 'aws', 'docker']
# 2279                                                  NaN
# 3482                                                ['c']
# ...                                                   ...
# 783724             ['r', 'python', 'matlab', 'java', 'c']
# 784558  ['python', 'r', 'ruby', 'ruby', 'go', 'java', ...
# 784798                     ['sas', 'sas', 'r', 'tableau']
# 784991                                              ['c']
# 785115  ['sql', 'python', 'r', 'excel', 'tableau', 'po...
#
#                                           job_type_skills
# 1059                                                  NaN
# 1705                       {'analyst_tools': ['tableau']}
# 2089    {'cloud': ['aws'], 'other': ['docker'], 'progr...
# 2279                                                  NaN
# 3482                               {'programming': ['c']}
# ...                                                   ...
# 783724  {'programming': ['r', 'python', 'matlab', 'jav...
# 784558  {'cloud': ['aws', 'redshift', 'oracle'], 'data...
# 784798  {'analyst_tools': ['sas', 'tableau'], 'program...
# 784991                             {'programming': ['c']}
# 785115  {'analyst_tools': ['excel', 'tableau', 'power ...
#
# [1705 rows x 17 columns]

# %%
# Extract month and year from job_posted_date in verbage format

df_kenya['job_posted_month'] = df_kenya['job_posted_date'].dt.strftime('%B') #refer from datetime documentation for % sighns

# %%
df_kenya
# Out:
#               job_title_short  \
# 1059           Cloud Engineer
# 1705             Data Analyst
# 2089           Data Scientist
# 2279           Data Scientist
# 3482             Data Analyst
# ...                       ...
# 783724         Data Scientist
# 784558         Cloud Engineer
# 784798  Senior Data Scientist
# 784991         Cloud Engineer
# 785115           Data Analyst
#
#                                                 job_title    job_location  \
# 1059                 Navigation & Infrastructure Engineer  Nairobi, Kenya
# 1705    Data Analytics Program Manager, VisionFund Int...  Nairobi, Kenya
# 2089                                       Data Scientist  Nairobi, Kenya
# 2279                                     Director of Data           Kenya
# 3482                                         Data Analyst  Nairobi, Kenya
# ...                                                   ...             ...
# 783724                   Data Science Intern at Dataposit  Nairobi, Kenya
# 784558     Data Insights Analytics Cloud Support Engineer  Nairobi, Kenya
# 784798                                     Senior Analyst  Nairobi, Kenya
# 784991                      Senior Engineering Technician  Nairobi, Kenya
# 785115                                      Data Analyst.  Nairobi, Kenya
#
#                    job_via         job_schedule_type  job_work_from_home  \
# 1059       via Trabajo.org                 Full-time               False
# 1705          via MyJobMag                 Full-time               False
# 2089       via Trabajo.org                 Full-time               False
# 2279       via Trabajo.org                 Full-time               False
# 3482          via UNjobnet                 Full-time               False
# ...                    ...                       ...                 ...
# 783724     via BeBee Kenya  Full-time and Internship               False
# 784558  via BrighterMonday                 Full-time               False
# 784798     via BeBee Kenya                 Full-time               False
# 784991     via Trabajo.org                 Full-time               False
# 785115     via Trabajo.org                 Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 1059             Kenya 2023-08-06 13:50:21                  False
# 1705             Kenya 2023-02-09 13:40:24                  False
# 2089             Kenya 2023-05-25 13:39:11                  False
# 2279             Kenya 2023-05-25 13:39:14                   True
# 3482             Kenya 2023-03-22 13:47:56                  False
# ...                ...                 ...                    ...
# 783724           Kenya 2023-09-18 06:19:21                  False
# 784558           Kenya 2023-11-16 06:31:16                  False
# 784798           Kenya 2023-10-29 06:22:25                  False
# 784991           Kenya 2023-08-12 06:19:49                   True
# 785115           Kenya 2023-05-31 06:25:53                  False
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 1059                   False       Kenya         NaN              NaN
# 1705                   False       Kenya         NaN              NaN
# 2089                   False       Kenya         NaN              NaN
# 2279                   False       Kenya         NaN              NaN
# 3482                   False       Kenya         NaN              NaN
# ...                      ...         ...         ...              ...
# 783724                 False       Kenya         NaN              NaN
# 784558                 False       Kenya         NaN              NaN
# 784798                 False       Kenya         NaN              NaN
# 784991                 False       Kenya         NaN              NaN
# 785115                 False       Kenya         NaN              NaN
#
#         salary_hour_avg                                       company_name  \
# 1059                NaN                                      Kenya Airways
# 1705                NaN                                 World Vision Kenya
# 2089                NaN                                     Medtronic Labs
# 2279                NaN                                      KOKO NETWORKS
# 3482                NaN         United Nations Human Settlements Programme
# ...                 ...                                                ...
# 783724              NaN                                          Dataposit
# 784558              NaN                                       confidential
# 784798              NaN                 Habitat for Humanity International
# 784991              NaN  Kenya Marine and Fisheries Research Institute ...
# 785115              NaN                                            Supreme
#
#                                                job_skills  \
# 1059                                                  NaN
# 1705                                          ['tableau']
# 2089                    ['go', 'python', 'aws', 'docker']
# 2279                                                  NaN
# 3482                                                ['c']
# ...                                                   ...
# 783724             ['r', 'python', 'matlab', 'java', 'c']
# 784558  ['python', 'r', 'ruby', 'ruby', 'go', 'java', ...
# 784798                     ['sas', 'sas', 'r', 'tableau']
# 784991                                              ['c']
# 785115  ['sql', 'python', 'r', 'excel', 'tableau', 'po...
#
#                                           job_type_skills job_posted_month
# 1059                                                  NaN           August
# 1705                       {'analyst_tools': ['tableau']}         February
# 2089    {'cloud': ['aws'], 'other': ['docker'], 'progr...              May
# 2279                                                  NaN              May
# 3482                               {'programming': ['c']}            March
# ...                                                   ...              ...
# 783724  {'programming': ['r', 'python', 'matlab', 'jav...        September
# 784558  {'cloud': ['aws', 'redshift', 'oracle'], 'data...         November
# 784798  {'analyst_tools': ['sas', 'tableau'], 'program...          October
# 784991                             {'programming': ['c']}           August
# 785115  {'analyst_tools': ['excel', 'tableau', 'power ...              May
#
# [1705 rows x 18 columns]

# %%
# putting months along the index in correct order and job titles along the columns

df_kenya_pivot = df_kenya.pivot_table(index='job_posted_month', columns='job_title', aggfunc='count')

# %%
df_kenya_pivot.reset_index(inplace=True)
df_kenya_pivot['month_no'] = pd.to_datetime(df_kenya_pivot['job_posted_month'], format='%B').dt.month
df_kenya_pivot.sort_values('month_no', inplace=True)
df_kenya_pivot.set_index('job_posted_month', inplace=True)
df_kenya_pivot.drop(columns='month_no', inplace=True)

df_kenya_pivot
# Out:
#                                        company_name  \
# job_title        2 Jobs In Kenya Today At Safaricom
# job_posted_month
# January                                         NaN
# February                                        NaN
# March                                           NaN
# April                                           NaN
# May                                             NaN
# June                                            NaN
# July                                            1.0
# August                                          NaN
# September                                       NaN
# October                                         NaN
# November                                        NaN
# December                                        NaN
#
#                                                       \
# job_title        2 Kenya Airways Jobs In Kenya Today
# job_posted_month
# January                                          NaN
# February                                         NaN
# March                                            NaN
# April                                            NaN
# May                                              NaN
# June                                             NaN
# July                                             NaN
# August                                           1.0
# September                                        NaN
# October                                          NaN
# November                                         NaN
# December                                         NaN
#
#                                                       \
# job_title        80354357 - Analyst, Finance Systems
# job_posted_month
# January                                          NaN
# February                                         1.0
# March                                            NaN
# April                                            NaN
# May                                              NaN
# June                                             NaN
# July                                             NaN
# August                                           NaN
# September                                        NaN
# October                                          NaN
# November                                         NaN
# December                                         NaN
#
#                                                                       \
# job_title        80419023 - Scientist, Data A/P Analyst AI Scientist
# job_posted_month
# January                                 NaN         NaN          NaN
# February                                NaN         NaN          NaN
# March                                   NaN         NaN          NaN
# April                                   NaN         NaN          NaN
# May                                     NaN         NaN          NaN
# June                                    NaN         NaN          1.0
# July                                    NaN         NaN          1.0
# August                                  NaN         1.0          NaN
# September                               1.0         NaN          NaN
# October                                 NaN         NaN          NaN
# November                                NaN         NaN          NaN
# December                                NaN         NaN          NaN
#
#                                                             \
# job_title        AI Software Engineer API Business Analyst
# job_posted_month
# January                           1.0                  NaN
# February                          1.0                  NaN
# March                             NaN                  NaN
# April                             NaN                  NaN
# May                               NaN                  NaN
# June                              NaN                  1.0
# July                              NaN                  NaN
# August                            NaN                  NaN
# September                         NaN                  NaN
# October                           NaN                  NaN
# November                          NaN                  NaN
# December                          NaN                  NaN
#
#                                                        \
# job_title        ASSOCIATE DATA SCIENTIST [Temporary]
# job_posted_month
# January                                           NaN
# February                                          NaN
# March                                             NaN
# April                                             NaN
# May                                               NaN
# June                                              NaN
# July                                              NaN
# August                                            1.0
# September                                         NaN
# October                                           NaN
# November                                          NaN
# December                                          NaN
#
#                                                                           ...  \
# job_title        Absa Bank Limited – Business Intelligence Data Engineer  ...
# job_posted_month                                                          ...
# January                                                         NaN       ...
# February                                                        NaN       ...
# March                                                           NaN       ...
# April                                                           NaN       ...
# May                                                             NaN       ...
# June                                                            1.0       ...
# July                                                            NaN       ...
# August                                                          NaN       ...
# September                                                       NaN       ...
# October                                                         NaN       ...
# November                                                        NaN       ...
# December                                                        NaN       ...
#
#                           search_location                          \
# job_title        associate data scientist data analysis assistant
# job_posted_month
# January                               NaN                     NaN
# February                              NaN                     NaN
# March                                 NaN                     NaN
# April                                 NaN                     NaN
# May                                   NaN                     1.0
# June                                  NaN                     NaN
# July                                  NaN                     NaN
# August                                1.0                     NaN
# September                             NaN                     NaN
# October                               NaN                     NaN
# November                              NaN                     NaN
# December                              NaN                     NaN
#
#                                                                        \
# job_title        data analyst data analyst/data modeler data engineer
# job_posted_month
# January                   1.0                       NaN           NaN
# February                  NaN                       NaN           NaN
# March                     NaN                       NaN           NaN
# April                     NaN                       NaN           NaN
# May                       NaN                       NaN           NaN
# June                      NaN                       NaN           NaN
# July                      NaN                       1.0           NaN
# August                    NaN                       1.0           NaN
# September                 1.0                       NaN           NaN
# October                   NaN                       NaN           NaN
# November                  NaN                       NaN           NaN
# December                  NaN                       NaN           1.0
#
#                                                  \
# job_title        data entry it service engineer
# job_posted_month
# January                 NaN                 NaN
# February                NaN                 NaN
# March                   1.0                 1.0
# April                   NaN                 NaN
# May                     NaN                 NaN
# June                    NaN                 NaN
# July                    NaN                 NaN
# August                  NaN                 NaN
# September               NaN                 NaN
# October                 NaN                 NaN
# November                NaN                 NaN
# December                NaN                 NaN
#
#                                                                      \
# job_title        mPharma – Business Analyst Intern sql data analyst
# job_posted_month
# January                                        NaN              NaN
# February                                       NaN              NaN
# March                                          NaN              NaN
# April                                          NaN              NaN
# May                                            NaN              NaN
# June                                           NaN              NaN
# July                                           1.0              2.0
# August                                         NaN              NaN
# September                                      NaN              NaN
# October                                        NaN              NaN
# November                                       NaN              NaN
# December                                       NaN              NaN
#
#
# job_title        world class data science and machine learning course program
# job_posted_month
# January                                                         1.0
# February                                                        NaN
# March                                                           NaN
# April                                                           NaN
# May                                                             NaN
# June                                                            NaN
# July                                                            NaN
# August                                                          NaN
# September                                                       NaN
# October                                                         NaN
# November                                                        NaN
# December                                                        NaN
#
# [12 rows x 16368 columns]

# %%
top_3 = df_kenya['job_title_short'].value_counts().head(3)
top_3.index.tolist()
# Out:
# ['Data Analyst', 'Software Engineer', 'Data Scientist']

# %%
top_3 = top_3.index.tolist()

# %%
import matplotlib.pyplot as plt


# aggregate counts across the top-level of the MultiIndex columns so job titles become columns
df_counts = df_kenya_pivot.groupby(level=1, axis=1).sum()

# plot the top 3 job titles
df_counts[top_3].plot(kind='line', marker='o')
plt.title('Monthly job postings for top 3 job titles in Kenya')
plt.ylabel('Count')
plt.xlabel('2023 Months')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 import matplotlib.pyplot as plt
#       4 # aggregate counts across the top-level of the MultiIndex columns so job titles become columns
# ----> 5 df_counts = df_kenya_pivot.groupby(level=1, axis=1).sum()
#       7 # plot the top 3 job titles
#       8 df_counts[top_3].plot(kind='line', marker='o')
#
# File c:\Users\byobd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# TypeError: DataFrame.groupby() got an unexpected keyword argument 'axis'
